# %% [markdown]
# ### Import python library

# %%
import tensorflow as tf
import numpy as np

from tensorflow import keras
from tensorflow.keras.utils import to_categorical

from tensorflow.keras.models import Sequential
# from tensorflow.keras.utils import np_utils
from tensorflow.keras.layers import Dense, LSTM, Dropout
import tensorflow.keras.backend as K 

from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.callbacks import EarlyStopping

from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler


import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# import plotly.express as px
# import plotly.graph_objects as go

from math import sqrt

# %% [markdown]
# ### 1. Read data: augment_24group_1620.csv필요

# %%
# PCT_lstm_train_X = pd.read_csv("ERA_lstm_final_train_X.csv")
# PCT_lstm_train_y = pd.read_csv("ERA_lstm_final_train_y.csv")

# PCT_lstm_test_X = pd.read_csv("ERA_lstm_final_test_X.csv")
# PCT_lstm_test_y = pd.read_csv("ERA_lstm_final_test_y.csv")

PCT_lstm_train_X = pd.read_csv("lstm_data/new_ERA_train_X.csv")
PCT_lstm_train_y = pd.read_csv("lstm_data/ERA_lstm_final_train_y.csv")

PCT_lstm_test_X = pd.read_csv("lstm_data/new_ERA_test_X.csv")
PCT_lstm_test_y = pd.read_csv("lstm_data/ERA_lstm_final_test_y.csv")

# %%
team = list(PCT_lstm_train_X.T_ID.unique())
year = list(PCT_lstm_train_y.YEAR.unique())

# %%
team, year
# Out:
# (['LG', 'HH', 'NC', 'HT', 'SK', 'KT', 'WO', 'LT', 'SS', 'OB'],
#  [2016, 2017, 2018, 2019])

# %% [markdown]
# #### 4) input shape로 변경 (row, timestep=2, feature)
#
# ex)
# timestep = 2
#
# * X_train_v 구성예시: [[1 ~ 24경기 데이터, 25 ~ 48경기 데이터], [49 ~ 72경기 데이터, 73 ~ 96경기 데이터] ]
# X_train_v.shape >> (2,2*x)             # x: 각 24group에 대한 변수 개수
# * y_train_v 구성예시: 97 ~ 120 경기 승률
#
# => reshape
#
# * X_train_v.shape >> (2,2,x)  # row, timestep, feature

# %% [markdown]
# ### 2. 모델 구성(LSTM)
# - optimizer: RMSprop -> lr(learning rate) 조절
# - LSTM: 모델이 계속 동일한 결과값이 나올 때, input 뉴런 개수를 늘려야 한다는 글을 읽고 계속 input 노드 개수를 바꿔주면서 모델 생성중
# - loss: MSE
#
# - early_stop: patience를 크게하면 과적합 되는 경우가 있어서 최대한 작게 설정해둠
# - batch_size: 모델이 계속 동일한 결과값이 나올 때, 데이터가 적어 batch size를 줄여보라는 글을 읽고 1로 설정해둠

# %%
model_dict = dict()
hist_dict = dict()
test_pred_df = pd.DataFrame([],columns = ['YEAR','T_ID','y','y_pred',"shift_ERA_1","shift_ERA_2",'rms','rms_avg'])

idx = 0
for y in year:
    tmp1 = PCT_lstm_train_X[PCT_lstm_train_X["YEAR"] == y]
    tmp2 = PCT_lstm_train_y[PCT_lstm_train_y["YEAR"] == y]
    tmp3 = PCT_lstm_test_X[PCT_lstm_test_X["YEAR"] == y]
    tmp4 = PCT_lstm_test_y[PCT_lstm_test_y["YEAR"] == y]
    for t in team:
        name = '{}{}'.format(y,t)
        print(name,"=======================================")
        
        X_train = tmp1[tmp1["T_ID"] == t].drop(["T_ID","YEAR"],axis = 1)
        y_train = tmp2[tmp2["T_ID"] == t].drop(["T_ID","YEAR"],axis=1)
        X_test = tmp3[tmp3["T_ID"] == t].drop(["T_ID","YEAR"],axis=1)
        y_test = tmp4[tmp4["T_ID"] == t].drop(["T_ID","YEAR"],axis=1)
        
        X_train_v = X_train.values
        y_train_v = y_train.values

        X_test_v = X_test.values
        y_test_v = y_test.values
        
        X_train_t = X_train_v.reshape(X_train_v.shape[0], 2,X_train_v.shape[1]//2)
        X_test_t = X_test_v.reshape(X_test_v.shape[0], 2,X_test_v.shape[1]//2)
        
        ## model
        K.clear_session() 

        model = Sequential()
        optimizer = Adam(lr=0.01)

        model.add(LSTM(100,input_shape = (2,X_train_v.shape[1]//2))) # (timestep, feature)
        model.add(Dense(1)) # output = 1
        model.compile(loss='mean_squared_error', optimizer=optimizer,metrics=['mae'])

        model.summary()
        
        
        early_stop = EarlyStopping(monitor='loss', mode = 'min',patience=2, verbose=1)

        hist1 = model.fit(X_train_t, y_train_v, epochs=100,
                  batch_size=1, verbose=1, callbacks=[early_stop])
        ##
        
        model_dict[name] = model
        hist_dict[name] = hist1
        
        y_pred = model.predict(X_test_t)
        rms = sqrt(mean_squared_error(y_test_v, y_pred))
        rms_avg = sqrt(mean_squared_error(y_test_v,[y_train.mean()[0]]))
        
        
        test_pred_df.loc[idx,:] = [y,t,y_test_v.reshape(-1)[0],y_pred.reshape(-1)[0],
                                  X_test.loc[X_test.index[0],["shift_ERA_1"]][0],
                                  X_test.loc[X_test.index[0],["shift_ERA_2"]][0], rms,rms_avg]

        idx += 1

test_pred_df[['y','y_pred',"shift_ERA_1","shift_ERA_2",'rms','rms_avg']] = test_pred_df[['y','y_pred',"shift_ERA_1","shift_ERA_2",'rms','rms_avg']].astype(float)
# Out:
# 2016LG =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 2s 49ms/sample - loss: 1.1193 - mae: 0.8475
# Epoch 2/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.7592 - mae: 0.7173
# Epoch 3/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.7583 - mae: 0.7486
# Epoch 4/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.9033 - mae: 0.7881
# Epoch 5/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.8440 - mae: 0.8143
# Epoch 00005: early stopping
# 2016HH =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 2s 40ms/sample - loss: 1.1105 - mae: 0.7219
# Epoch 2/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.4852 - mae: 0.5796
# Epoch 3/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.4986 - mae: 0.6081
# Epoch 4/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.4589 - mae: 0.5951
# Epoch 5/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.7001 - mae: 0.6979
# Epoch 6/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.4666 - mae: 0.5860
# Epoch 00006: early stopping
# 2016NC =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 2s 41ms/sample - loss: 0.7803 - mae: 0.4852
# Epoch 2/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.1748 - mae: 0.3374
# Epoch 3/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.2214 - mae: 0.3882
# Epoch 4/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.1744 - mae: 0.3553
# Epoch 5/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.1556 - mae: 0.3356
# Epoch 6/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.1864 - mae: 0.3510
# Epoch 7/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.1618 - mae: 0.3314
# Epoch 00007: early stopping
# 2016HT =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 2s 38ms/sample - loss: 0.8780 - mae: 0.5807
# Epoch 2/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.2395 - mae: 0.3610
# Epoch 3/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.3290 - mae: 0.4957
# Epoch 4/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.2711 - mae: 0.4326
# Epoch 00004: early stopping
# 2016SK =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 2s 40ms/sample - loss: 1.6854 - mae: 0.8209
# Epoch 2/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.8259 - mae: 0.7629
# Epoch 3/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.5272 - mae: 0.6490
# Epoch 4/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.5704 - mae: 0.6537
# Epoch 5/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.6406 - mae: 0.6914
# Epoch 00005: early stopping
# 2016KT =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 2s 47ms/sample - loss: 1.9150 - mae: 0.7622
# Epoch 2/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.4119 - mae: 0.5284
# Epoch 3/100
# 49/49 [==============================] - 0s 5ms/sample - loss: 0.5966 - mae: 0.6338
# Epoch 4/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.3895 - mae: 0.5349
# Epoch 5/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.4184 - mae: 0.5661
# Epoch 6/100
# 49/49 [==============================] - 0s 5ms/sample - loss: 0.4125 - mae: 0.5288
# Epoch 00006: early stopping
# 2016WO =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 3s 56ms/sample - loss: 1.2502 - mae: 0.7514
# Epoch 2/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.4877 - mae: 0.6016
# Epoch 3/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.6813 - mae: 0.6965
# Epoch 4/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.4862 - mae: 0.6104
# Epoch 5/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.4450 - mae: 0.5934
# Epoch 6/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.4662 - mae: 0.6065
# Epoch 7/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.4229 - mae: 0.5802
# Epoch 8/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.5055 - mae: 0.6149
# Epoch 9/100
# 49/49 [==============================] - 0s 5ms/sample - loss: 0.4882 - mae: 0.6170
# Epoch 00009: early stopping
# 2016LT =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 3s 59ms/sample - loss: 1.0780 - mae: 0.6089
# Epoch 2/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.2076 - mae: 0.3747
# Epoch 3/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.2184 - mae: 0.3885
# Epoch 4/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.2012 - mae: 0.3698
# Epoch 5/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.2042 - mae: 0.3573
# Epoch 6/100
# 49/49 [==============================] - 0s 5ms/sample - loss: 0.2156 - mae: 0.3806
# Epoch 00006: early stopping
# 2016SS =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 3s 66ms/sample - loss: 0.7553 - mae: 0.5740
# Epoch 2/100
# 49/49 [==============================] - 0s 5ms/sample - loss: 0.1783 - mae: 0.3703
# Epoch 3/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.2095 - mae: 0.3762
# Epoch 4/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.1950 - mae: 0.3558
# Epoch 00004: early stopping
# 2016OB =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 2s 38ms/sample - loss: 1.2315 - mae: 0.7404
# Epoch 2/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.5703 - mae: 0.6220
# Epoch 3/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.5123 - mae: 0.5883
# Epoch 4/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.5526 - mae: 0.6077
# Epoch 5/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.4790 - mae: 0.5599
# Epoch 6/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.4702 - mae: 0.5518
# Epoch 7/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.6083 - mae: 0.6529
# Epoch 8/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.5341 - mae: 0.5841
# Epoch 00008: early stopping
# 2017LG =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 2s 38ms/sample - loss: 0.9799 - mae: 0.5870
# Epoch 2/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 0.3354 - mae: 0.4795
# Epoch 3/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 0.2618 - mae: 0.4276
# Epoch 4/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 0.2509 - mae: 0.4289
# Epoch 5/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 0.2483 - mae: 0.4204
# Epoch 6/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.2709 - mae: 0.4522
# Epoch 7/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.2162 - mae: 0.3919
# Epoch 8/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 0.2649 - mae: 0.4221
# Epoch 9/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.2242 - mae: 0.3962
# Epoch 00009: early stopping
# 2017HH =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 2s 41ms/sample - loss: 1.9482 - mae: 0.9158
# Epoch 2/100
# 49/49 [==============================] - 0s 5ms/sample - loss: 0.8858 - mae: 0.7835
# Epoch 3/100
# 49/49 [==============================] - 0s 6ms/sample - loss: 0.7645 - mae: 0.6965
# Epoch 4/100
# 49/49 [==============================] - 0s 7ms/sample - loss: 0.7479 - mae: 0.6618
# Epoch 5/100
# 49/49 [==============================] - 0s 6ms/sample - loss: 0.8990 - mae: 0.7723
# Epoch 6/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.9866 - mae: 0.7456
# Epoch 00006: early stopping
# 2017NC =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 3s 68ms/sample - loss: 1.4536 - mae: 0.8887
# Epoch 2/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.8255 - mae: 0.7490
# Epoch 3/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.8898 - mae: 0.7743
# Epoch 4/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.8446 - mae: 0.7466
# Epoch 00004: early stopping
# 2017HT =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 2s 36ms/sample - loss: 1.1893 - mae: 0.6105
# Epoch 2/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.2121 - mae: 0.3389
# Epoch 3/100
# 49/49 [==============================] - 0s 5ms/sample - loss: 0.2064 - mae: 0.3642
# Epoch 4/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.1976 - mae: 0.3546
# Epoch 5/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.2929 - mae: 0.4492
# Epoch 6/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.2618 - mae: 0.3796
# Epoch 00006: early stopping
# 2017SK =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 2s 34ms/sample - loss: 2.2327 - mae: 1.0820
# Epoch 2/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 1.2737 - mae: 0.9180 0s - loss: 1.2252 - mae: 0.899
# Epoch 3/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 1.2322 - mae: 0.9247
# Epoch 4/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 1.0471 - mae: 0.8753
# Epoch 5/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 1.1461 - mae: 0.8804
# Epoch 6/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 1.1163 - mae: 0.8461
# Epoch 00006: early stopping
# 2017KT =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 2s 43ms/sample - loss: 1.4232 - mae: 0.7425
# Epoch 2/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 0.6727 - mae: 0.6481
# Epoch 3/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 0.6911 - mae: 0.6853
# Epoch 4/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.8122 - mae: 0.7446
# Epoch 00004: early stopping
# 2017WO =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 2s 32ms/sample - loss: 1.0306 - mae: 0.5874
# Epoch 2/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.3213 - mae: 0.4552
# Epoch 3/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.2979 - mae: 0.4804
# Epoch 4/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.3364 - mae: 0.5075
# Epoch 5/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.3242 - mae: 0.4607
# Epoch 00005: early stopping
# 2017LT =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 2s 32ms/sample - loss: 1.9099 - mae: 0.9365
# Epoch 2/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 1.1064 - mae: 0.7995
# Epoch 3/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 1.2644 - mae: 0.9236
# Epoch 4/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.9744 - mae: 0.7456
# Epoch 5/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 1.0639 - mae: 0.8306
# Epoch 6/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 1.1019 - mae: 0.7694
# Epoch 00006: early stopping
# 2017SS =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 2s 33ms/sample - loss: 0.9809 - mae: 0.5362
# Epoch 2/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 0.3124 - mae: 0.4070
# Epoch 3/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.2442 - mae: 0.3905
# Epoch 4/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.2753 - mae: 0.3801
# Epoch 5/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.3197 - mae: 0.4419
# Epoch 00005: early stopping
# 2017OB =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 2s 44ms/sample - loss: 2.3797 - mae: 1.2691
# Epoch 2/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 1.6057 - mae: 1.1443
# Epoch 3/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 1.6064 - mae: 1.1259
# Epoch 4/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 1.6948 - mae: 1.2042
# Epoch 00004: early stopping
# 2018LG =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 2s 38ms/sample - loss: 2.7665 - mae: 1.0536
# Epoch 2/100
# 49/49 [==============================] - 0s 5ms/sample - loss: 1.0036 - mae: 0.8507
# Epoch 3/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 1.0793 - mae: 0.8675
# Epoch 4/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 1.1564 - mae: 0.9081
# Epoch 00004: early stopping
# 2018HH =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 2s 44ms/sample - loss: 1.2540 - mae: 0.8519
# Epoch 2/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.3172 - mae: 0.4560
# Epoch 3/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.3844 - mae: 0.4840
# Epoch 4/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.3878 - mae: 0.5156
# Epoch 00004: early stopping
# 2018NC =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 2s 37ms/sample - loss: 0.8792 - mae: 0.4491
# Epoch 2/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.0800 - mae: 0.2220
# Epoch 3/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.1073 - mae: 0.2668
# Epoch 4/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.1293 - mae: 0.2710 0s - loss: 0.1309 - mae: 0.28
# Epoch 00004: early stopping
# 2018HT =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 3s 59ms/sample - loss: 1.2491 - mae: 0.5957
# Epoch 2/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.2759 - mae: 0.4035
# Epoch 3/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.3146 - mae: 0.4823
# Epoch 4/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.2667 - mae: 0.4230
# Epoch 5/100
# 49/49 [==============================] - 0s 5ms/sample - loss: 0.2286 - mae: 0.3807
# Epoch 6/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.2253 - mae: 0.4044
# Epoch 7/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.2703 - mae: 0.4233
# Epoch 8/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.2685 - mae: 0.4011
# Epoch 00008: early stopping
# 2018SK =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 2s 31ms/sample - loss: 1.4287 - mae: 0.9055
# Epoch 2/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.7463 - mae: 0.7368
# Epoch 3/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 0.8659 - mae: 0.7505
# Epoch 4/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 0.8684 - mae: 0.7654
# Epoch 00004: early stopping
# 2018KT =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 1s 30ms/sample - loss: 0.9240 - mae: 0.4961
# Epoch 2/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 0.1645 - mae: 0.3392
# Epoch 3/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 0.1370 - mae: 0.3252
# Epoch 4/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.1339 - mae: 0.2948
# Epoch 5/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.1180 - mae: 0.2778
# Epoch 6/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 0.0948 - mae: 0.2616
# Epoch 7/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 0.1385 - mae: 0.3080
# Epoch 8/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 0.1855 - mae: 0.3556
# Epoch 00008: early stopping
# 2018WO =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 1s 30ms/sample - loss: 0.7911 - mae: 0.4456
# Epoch 2/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.0974 - mae: 0.2431
# Epoch 3/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 0.0879 - mae: 0.2422
# Epoch 4/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.1381 - mae: 0.2934
# Epoch 5/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 0.0952 - mae: 0.2445
# Epoch 00005: early stopping
# 2018LT =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 1s 30ms/sample - loss: 1.1032 - mae: 0.6300
# Epoch 2/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 0.2648 - mae: 0.4204
# Epoch 3/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 0.3318 - mae: 0.4708
# Epoch 4/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.2972 - mae: 0.4390
# Epoch 00004: early stopping
# 2018SS =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 2s 48ms/sample - loss: 2.1890 - mae: 1.1098
# Epoch 2/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 1.4886 - mae: 1.1003
# Epoch 3/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 1.4076 - mae: 1.0557
# Epoch 4/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 1.5144 - mae: 1.1130
# Epoch 5/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 1.2031 - mae: 0.9810
# Epoch 6/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 1.4413 - mae: 1.0515
# Epoch 7/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 1.5857 - mae: 1.0851
# Epoch 00007: early stopping
# 2018OB =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 2s 31ms/sample - loss: 1.1886 - mae: 0.7835
# Epoch 2/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.5391 - mae: 0.5866
# Epoch 3/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.4427 - mae: 0.5622
# Epoch 4/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.4757 - mae: 0.5321
# Epoch 5/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.4726 - mae: 0.5694
# Epoch 00005: early stopping
# 2019LG =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 2s 31ms/sample - loss: 1.4308 - mae: 0.9170
# Epoch 2/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 0.6507 - mae: 0.6673
# Epoch 3/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 0.6048 - mae: 0.6407
# Epoch 4/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 0.3074 - mae: 0.4290
# Epoch 5/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 0.1956 - mae: 0.3403
# Epoch 6/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 0.4098 - mae: 0.5018
# Epoch 7/100
# 49/49 [==============================] - 0s 2ms/sample - loss: 0.2444 - mae: 0.3768
# Epoch 00007: early stopping
# 2019HH =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 2s 34ms/sample - loss: 0.8721 - mae: 0.6883
# Epoch 2/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.6338 - mae: 0.6340
# Epoch 3/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.5542 - mae: 0.5878
# Epoch 4/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.5142 - mae: 0.5725
# Epoch 5/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.4929 - mae: 0.5465
# Epoch 6/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.5486 - mae: 0.5806
# Epoch 7/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.5055 - mae: 0.5363
# Epoch 00007: early stopping
# 2019NC =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 2s 39ms/sample - loss: 1.0861 - mae: 0.8633
# Epoch 2/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.5856 - mae: 0.6936
# Epoch 3/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.5770 - mae: 0.6062
# Epoch 4/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.4092 - mae: 0.5632
# Epoch 5/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.2499 - mae: 0.4084
# Epoch 6/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.0971 - mae: 0.2572
# Epoch 7/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.0562 - mae: 0.1875
# Epoch 8/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.0893 - mae: 0.2413
# Epoch 9/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.0853 - mae: 0.2334
# Epoch 00009: early stopping
# 2019HT =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 2s 34ms/sample - loss: 0.9541 - mae: 0.5391
# Epoch 2/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.1490 - mae: 0.3209
# Epoch 3/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.2156 - mae: 0.3870
# Epoch 4/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.1578 - mae: 0.3364
# Epoch 00004: early stopping
# 2019SK =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 3s 54ms/sample - loss: 0.3945 - mae: 0.3711
# Epoch 2/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.0965 - mae: 0.2697
# Epoch 3/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.0814 - mae: 0.2382
# Epoch 4/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.0880 - mae: 0.2460
# Epoch 5/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.0908 - mae: 0.2470
# Epoch 00005: early stopping
# 2019KT =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 2s 32ms/sample - loss: 0.8351 - mae: 0.5495
# Epoch 2/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.3630 - mae: 0.4629
# Epoch 3/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.3995 - mae: 0.4986
# Epoch 4/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.3627 - mae: 0.4715
# Epoch 5/100
# 49/49 [==============================] - ETA: 0s - loss: 0.3511 - mae: 0.467 - 0s 3ms/sample - loss: 0.3304 - mae: 0.4496
# Epoch 6/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.4101 - mae: 0.5143
# Epoch 7/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.3944 - mae: 0.5106
# Epoch 00007: early stopping
# 2019WO =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 1s 30ms/sample - loss: 0.5195 - mae: 0.5057
# Epoch 2/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.1732 - mae: 0.3258
# Epoch 3/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.1954 - mae: 0.3458
# Epoch 4/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.1789 - mae: 0.3320
# Epoch 00004: early stopping
# 2019LT =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 2s 31ms/sample - loss: 0.7672 - mae: 0.5812
# Epoch 2/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.3203 - mae: 0.4788
# Epoch 3/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.2928 - mae: 0.4308
# Epoch 4/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.3743 - mae: 0.5041
# Epoch 5/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.4390 - mae: 0.5231
# Epoch 00005: early stopping
# 2019SS =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 1s 30ms/sample - loss: 0.6844 - mae: 0.5271
# Epoch 2/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.3386 - mae: 0.4454
# Epoch 3/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.3121 - mae: 0.4407
# Epoch 4/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.2507 - mae: 0.4267
# Epoch 5/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.2581 - mae: 0.3957
# Epoch 6/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.2744 - mae: 0.3930
# Epoch 00006: early stopping
# 2019OB =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               76400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 76,501
# Trainable params: 76,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49 samples
# Epoch 1/100
# 49/49 [==============================] - 2s 31ms/sample - loss: 0.4203 - mae: 0.3655
# Epoch 2/100
# 49/49 [==============================] - 0s 4ms/sample - loss: 0.1439 - mae: 0.3021
# Epoch 3/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.0983 - mae: 0.2517
# Epoch 4/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.1354 - mae: 0.2815
# Epoch 5/100
# 49/49 [==============================] - 0s 3ms/sample - loss: 0.1167 - mae: 0.2576
# Epoch 00005: early stopping

# %%
mean_squared_error(test_pred_df['y'],test_pred_df['y_pred'])
# Out:
# 0.8959612564839935

# %%
test_pred_df.groupby(["YEAR"]).mean()
# Out:
#              y    y_pred  shift_ERA_1  shift_ERA_2       rms   rms_avg
# YEAR
# 2016  4.972786  5.447972     5.462381     5.436733  0.671679  0.669363
# 2017  5.225316  5.387359     4.865418     5.241630  0.709173  0.738538
# 2018  5.383612  5.305061     5.780409     4.984139  0.419401  0.551212
# 2019  3.400941  4.314971     4.366891     4.444551  1.087543  1.036635

# %%
test_pred_df
# Out:
#     YEAR T_ID         y    y_pred  shift_ERA_1  shift_ERA_2       rms  \
# 0   2016   LG  3.649770  5.271198     5.400000     5.551402  1.621429
# 1   2016   HH  5.258114  5.257411     6.412500     5.010736  0.000703
# 2   2016   NC  3.575342  5.326654     5.086342     5.057143  1.751311
# 3   2016   HT  4.120827  5.020864     5.957746     4.779503  0.900038
# 4   2016   SK  5.144882  4.941212     5.646226     5.391576  0.203670
# 5   2016   KT  6.314516  7.165537     5.736422     7.130435  0.851021
# 6   2016   WO  5.704839  5.162143     4.584112     5.039454  0.542695
# 7   2016   LT  5.849294  5.721380     5.314286     5.869565  0.127914
# 8   2016   SS  5.400000  6.010520     6.214286     5.070229  0.610520
# 9   2016   OB  4.710280  4.602796     4.271889     5.467290  0.107484
# 10  2017   LG  4.506891  5.239375     5.323344     4.843994  0.732484
# 11  2017   HH  5.509346  5.389902     4.222749     6.910970  0.119444
# 12  2017   NC  6.275229  5.212692     4.274295     4.693780  1.062537
# 13  2017   HT  4.981395  5.430459     5.322734     4.520548  0.449064
# 14  2017   SK  4.909091  6.289423     4.932692     6.998400  1.380333
# 15  2017   KT  5.593458  6.587831     6.240770     6.058537  0.994373
# 16  2017   WO  5.852848  4.586073     4.212168     4.846154  1.266775
# 17  2017   LT  4.075472  4.336091     4.087156     3.511211  0.260619
# 18  2017   SS  6.304147  6.017252     6.557143     5.637363  0.286895
# 19  2017   OB  4.245283  4.784494     3.481132     4.395349  0.539211
# 20  2018   LG  5.239437  5.488373     7.232143     5.794521  0.248936
# 21  2018   HH  5.551402  4.744907     6.244019     3.905660  0.806495
# 22  2018   NC  6.100962  4.925139     4.973684     5.260870  1.175822
# 23  2018   HT  5.558824  5.557596     6.473186     5.511076  0.001227
# 24  2018   SK  5.238170  5.303927     5.509346     3.327613  0.065757
# 25  2018   KT  5.576087  5.722378     5.543887     4.965997  0.146291
# 26  2018   WO  5.630332  5.124120     4.965997     5.631902  0.506212
# 27  2018   LT  4.833333  4.939920     6.330144     5.474085  0.106587
# 28  2018   SS  5.350230  5.848652     4.927914     4.754717  0.498422
# 29  2018   OB  4.757342  5.395600     5.603774     5.214953  0.638259
# 30  2019   LG  3.146457  5.539750     5.197183     5.118483  2.393293
# 31  2019   HH  3.051084  5.396345     5.652174     6.014218  2.345262
# 32  2019   NC  3.317263  3.138077     3.474419     4.704867  0.179186
# 33  2019   HT  3.669903  5.003315     4.415888     4.971429  1.333413
# 34  2019   SK  3.893819  3.205445     3.118671     3.489231  0.688375
# 35  2019   KT  3.438679  3.645432     3.641860     3.851227  0.206753
# 36  2019   WO  2.014286  3.765453     4.285054     2.801887  1.751167
# 37  2019   LT  3.608696  4.499340     4.563981     4.699367  0.890644
# 38  2019   SS  4.349282  4.881787     5.668740     4.822967  0.532505
# 39  2019   OB  3.519939  4.074768     3.650943     3.971831  0.554829
#
#      rms_avg
# 0   1.736086
# 1   0.147947
# 2   1.669293
# 3   1.158068
# 4   0.147898
# 5   0.622919
# 6   0.622746
# 7   0.074993
# 8   0.297577
# 9   0.216106
# 10  0.543503
# 11  0.699209
# 12  1.555580
# 13  0.210642
# 14  0.926630
# 15  0.646281
# 16  1.143211
# 17  0.504781
# 18  0.664801
# 19  0.490742
# 20  0.703889
# 21  0.617303
# 22  0.952907
# 23  0.245216
# 24  0.830245
# 25  0.084447
# 26  0.440391
# 27  0.762361
# 28  0.154974
# 29  0.720385
# 30  1.608301
# 31  2.435057
# 32  0.987767
# 33  0.841153
# 34  0.729874
# 35  0.665475
# 36  1.348384
# 37  0.727015
# 38  0.585413
# 39  0.437913

# %%
from sklearn.metrics import r2_score
tmp = test_pred_df.copy()
# tmp['half']= 0.5
r2_y_predict = r2_score(tmp['y'], tmp['y_pred'])
r2_y_predict
# Out:
# 0.17232939349187404
