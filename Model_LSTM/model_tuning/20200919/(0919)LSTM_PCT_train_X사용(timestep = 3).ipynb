# %% [markdown]
# ### Import python library

# %%
import tensorflow as tf
import numpy as np

from tensorflow import keras
from tensorflow.keras.utils import to_categorical

from tensorflow.keras.models import Sequential
# from tensorflow.keras.utils import np_utils
from tensorflow.keras.layers import Dense, LSTM, Dropout
import tensorflow.keras.backend as K 

from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.callbacks import EarlyStopping

from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler


import pandas as pd

import matplotlib.pyplot as plt
# import seaborn as sns
# import plotly.express as px
# import plotly.graph_objects as go

from math import sqrt

# %% [markdown]
# ### 1. Read data: augment_24group_1620.csv필요

# %%
timestep = 3

# %%
PCT_lstm_train_X = pd.read_csv("PCT_lstm_final_train_X33.csv")
PCT_lstm_train_y = pd.read_csv("PCT_lstm_final_train_y33.csv")

PCT_lstm_test_X = pd.read_csv("PCT_lstm_final_test_X33.csv")
PCT_lstm_test_y = pd.read_csv("PCT_lstm_final_test_y33.csv")

# %%
team = list(PCT_lstm_train_X.T_ID.unique())
year = list(PCT_lstm_train_y.YEAR.unique())

# %%
team, year
# Out:
# (['LG', 'HH', 'NC', 'HT', 'SK', 'KT', 'WO', 'LT', 'SS', 'OB'],
#  [2016, 2017, 2018, 2019])

# %% [markdown]
# #### 4) input shape로 변경 (row, timestep=2, feature)
#
# ex)
# timestep = 2
#
# * X_train_v 구성예시: [[1 ~ 24경기 데이터, 25 ~ 48경기 데이터], [49 ~ 72경기 데이터, 73 ~ 96경기 데이터] ]
# X_train_v.shape >> (2,2*x)             # x: 각 24group에 대한 변수 개수
# * y_train_v 구성예시: 97 ~ 120 경기 승률
#
# => reshape
#
# * X_train_v.shape >> (2,2,x)  # row, timestep, feature

# %% [markdown]
# ### 2. 모델 구성(LSTM)
# - optimizer: Adam -> lr(learning rate) 조절
# - LSTM: 모델이 계속 동일한 결과값이 나올 때, input 뉴런 개수를 늘려야 한다는 글을 읽고 계속 input 노드 개수를 바꿔주면서 모델 생성중
# - loss: MSE
#
# - early_stop: patience를 크게하면 과적합 되는 경우가 있어서 최대한 작게 설정해둠
# - batch_size: 모델이 계속 동일한 결과값이 나올 때, 데이터가 적어 batch size를 줄여보라는 글을 읽고 1로 설정해둠

# %%
model_dict = dict()
hist_dict = dict()
test_pred_df = pd.DataFrame([],columns = ['YEAR','T_ID','y','y_pred',"shift_PCT_1","shift_PCT_2","shift_PCT_3",'rms','rms0.5'])

idx = 0
for y in year:
    tmp1 = PCT_lstm_train_X[PCT_lstm_train_X["YEAR"] == y]
    tmp2 = PCT_lstm_train_y[PCT_lstm_train_y["YEAR"] == y]
    tmp3 = PCT_lstm_test_X[PCT_lstm_test_X["YEAR"] == y]
    tmp4 = PCT_lstm_test_y[PCT_lstm_test_y["YEAR"] == y]
    for t in team:
        name = '{}{}'.format(y,t)
        print(name,"=======================================")
        
        X_train = tmp1[tmp1["T_ID"] == t].drop(["T_ID","YEAR"],axis = 1)
        y_train = tmp2[tmp2["T_ID"] == t].drop(["T_ID","YEAR"],axis=1)
        X_test = tmp3[tmp3["T_ID"] == t].drop(["T_ID","YEAR"],axis=1)
        y_test = tmp4[tmp4["T_ID"] == t].drop(["T_ID","YEAR"],axis=1)
        
        X_train_v = X_train.values
        y_train_v = y_train.values

        X_test_v = X_test.values
        y_test_v = y_test.values
        
        X_train_t = X_train_v.reshape(X_train_v.shape[0], timestep,X_train_v.shape[1]//timestep)
        X_test_t = X_test_v.reshape(X_test_v.shape[0], timestep,X_test_v.shape[1]//timestep)
        
        
        ## model
        K.clear_session() 

        model = Sequential()
        optimizer = Adam(lr=0.01)
#         optimizer = RMSprop(lr=0.01, rho=0.9, epsilon=None, decay=0.0)

        model.add(LSTM(100,input_shape = (timestep,X_train_v.shape[1]//timestep))) # (timestep, feature)
        model.add(Dense(1)) # output = 1
        model.compile(loss='mean_squared_error', optimizer=optimizer,metrics=['mae'])

        model.summary()
        
#         hist1 = model.fit(X_train_t, y_train_v, epochs=100, batch_size=1, verbose=1)
        
        early_stop = EarlyStopping(monitor='loss', mode = 'min',patience=2, verbose=1)

        hist1 = model.fit(X_train_t, y_train_v, epochs=100,
                  batch_size=2, verbose=1, callbacks=[early_stop])
        ##
        
        model_dict[name] = model
        hist_dict[name] = hist1
        
        y_pred = model.predict(X_test_t)
        rms = sqrt(mean_squared_error(y_test_v, y_pred))
        rms05 = sqrt(mean_squared_error(y_test_v,[0.5]))
        
        
        test_pred_df.loc[idx,:] = [y,t,y_test_v.reshape(-1)[0],y_pred.reshape(-1)[0],
                                  X_test.loc[X_test.index[0],["shift_PCT_1"]][0],
                                  X_test.loc[X_test.index[0],["shift_PCT_2"]][0],
                                   X_test.loc[X_test.index[0],["shift_PCT_3"]][0],rms,rms05]

        idx += 1

test_pred_df[['y','y_pred',"shift_PCT_1","shift_PCT_2","shift_PCT_3",'rms','rms0.5']] = test_pred_df[['y','y_pred',"shift_PCT_1","shift_PCT_2","shift_PCT_3",'rms','rms0.5']].astype(float)
# Out:
# 2016LG =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 1s 55ms/sample - loss: 1.7068 - mae: 0.9164
# Epoch 2/100
# 25/25 [==============================] - 0s 2ms/sample - loss: 0.0124 - mae: 0.0886
# Epoch 3/100
# 25/25 [==============================] - 0s 2ms/sample - loss: 0.0099 - mae: 0.0745
# Epoch 4/100
# 25/25 [==============================] - 0s 2ms/sample - loss: 0.0042 - mae: 0.0526
# Epoch 5/100
# 25/25 [==============================] - 0s 2ms/sample - loss: 0.0034 - mae: 0.0420
# Epoch 6/100
# 25/25 [==============================] - 0s 2ms/sample - loss: 0.0033 - mae: 0.0398
# Epoch 7/100
# 25/25 [==============================] - ETA: 0s - loss: 8.0092e-04 - mae: 0.023 - 0s 2ms/sample - loss: 0.0034 - mae: 0.0424
# Epoch 8/100
# 25/25 [==============================] - 0s 2ms/sample - loss: 0.0035 - mae: 0.0402
# Epoch 00008: early stopping
# 2016HH =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 4s 140ms/sample - loss: 1.5882 - mae: 0.8641
# Epoch 2/100
# 25/25 [==============================] - 0s 4ms/sample - loss: 0.0093 - mae: 0.0786
# Epoch 3/100
# 25/25 [==============================] - 0s 4ms/sample - loss: 0.0093 - mae: 0.0824
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0048 - mae: 0.0524
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0039 - mae: 0.0539
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0043 - mae: 0.0601
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0040 - mae: 0.0543
# Epoch 00007: early stopping
# 2016NC =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 1s 53ms/sample - loss: 1.9867 - mae: 0.9934
# Epoch 2/100
# 25/25 [==============================] - 0s 4ms/sample - loss: 0.0220 - mae: 0.1355
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0075 - mae: 0.0684
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0025 - mae: 0.0426
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0012 - mae: 0.0294
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 9.2642e-04 - mae: 0.0245
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 9.5145e-04 - mae: 0.0261
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 8.9976e-04 - mae: 0.0253
# Epoch 9/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 8.2812e-04 - mae: 0.0253
# Epoch 10/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 8.2087e-04 - mae: 0.0253
# Epoch 11/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 8.5206e-04 - mae: 0.0258
# Epoch 12/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 8.0579e-04 - mae: 0.0250
# Epoch 13/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 8.1916e-04 - mae: 0.0253
# Epoch 14/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 8.6139e-04 - mae: 0.0255
# Epoch 00014: early stopping
# 2016HT =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 1s 54ms/sample - loss: 1.3419 - mae: 0.8703
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0231 - mae: 0.1400
# Epoch 3/100
# 25/25 [==============================] - 0s 4ms/sample - loss: 0.0053 - mae: 0.0572
# Epoch 4/100
# 25/25 [==============================] - 0s 4ms/sample - loss: 0.0043 - mae: 0.0588
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0013 - mae: 0.0271
# Epoch 6/100
# 25/25 [==============================] - 0s 4ms/sample - loss: 0.0013 - mae: 0.0273
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0013 - mae: 0.0312
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0014 - mae: 0.0253
# Epoch 00008: early stopping
# 2016SK =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 1s 58ms/sample - loss: 1.3845 - mae: 0.8651
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0136 - mae: 0.1030
# Epoch 3/100
# 25/25 [==============================] - 0s 4ms/sample - loss: 0.0049 - mae: 0.0538
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0025 - mae: 0.0442
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 9.6118e-04 - mae: 0.0241
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 8.5153e-04 - mae: 0.0260
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 9.4468e-04 - mae: 0.0277
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 9.0844e-04 - mae: 0.0240
# Epoch 00008: early stopping
# 2016KT =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 1s 58ms/sample - loss: 2.1584 - mae: 1.0008
# Epoch 2/100
# 25/25 [==============================] - 0s 4ms/sample - loss: 0.0472 - mae: 0.2002
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0121 - mae: 0.0948
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0023 - mae: 0.0379
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0027 - mae: 0.0409
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0013 - mae: 0.0292
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0016 - mae: 0.0327
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0016 - mae: 0.0334
# Epoch 00008: early stopping
# 2016WO =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 1s 57ms/sample - loss: 0.9929 - mae: 0.7466
# Epoch 2/100
# 25/25 [==============================] - 0s 4ms/sample - loss: 0.0175 - mae: 0.1183
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0057 - mae: 0.0619
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0031 - mae: 0.0439
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0025 - mae: 0.0433
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0020 - mae: 0.0361
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0017 - mae: 0.0336
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0018 - mae: 0.0338
# Epoch 9/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0018 - mae: 0.0342
# Epoch 00009: early stopping
# 2016LT =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 1s 56ms/sample - loss: 1.2919 - mae: 0.7820
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0123 - mae: 0.0881
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0099 - mae: 0.0807
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0063 - mae: 0.0635
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0058 - mae: 0.0670
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0063 - mae: 0.0660
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0056 - mae: 0.0668
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0055 - mae: 0.0634
# Epoch 9/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0059 - mae: 0.0616
# Epoch 10/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0068 - mae: 0.0750
# Epoch 00010: early stopping
# 2016SS =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 1s 57ms/sample - loss: 1.0518 - mae: 0.7836
# Epoch 2/100
# 25/25 [==============================] - 0s 4ms/sample - loss: 0.0185 - mae: 0.1216
# Epoch 3/100
# 25/25 [==============================] - 0s 4ms/sample - loss: 0.0084 - mae: 0.0721
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0044 - mae: 0.0546
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0020 - mae: 0.0367
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0018 - mae: 0.0345
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0018 - mae: 0.0330
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0016 - mae: 0.0316
# Epoch 9/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0016 - mae: 0.0313
# Epoch 10/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0017 - mae: 0.0328
# Epoch 00010: early stopping
# 2016OB =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 1s 55ms/sample - loss: 2.0894 - mae: 1.0011
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0355 - mae: 0.1585
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0188 - mae: 0.1144
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0113 - mae: 0.0866
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0141 - mae: 0.1009
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0095 - mae: 0.0865
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0111 - mae: 0.0917
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0102 - mae: 0.0908
# Epoch 00008: early stopping
# 2017LG =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 1s 55ms/sample - loss: 1.4170 - mae: 0.8410
# Epoch 2/100
# 25/25 [==============================] - 0s 4ms/sample - loss: 0.0153 - mae: 0.0915
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0145 - mae: 0.0978
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0112 - mae: 0.0908
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0108 - mae: 0.0895
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0105 - mae: 0.0884
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0116 - mae: 0.0934
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0120 - mae: 0.0935
# Epoch 00008: early stopping
# 2017HH =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 3s 116ms/sample - loss: 1.1733 - mae: 0.8207
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0389 - mae: 0.1742
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0196 - mae: 0.1164
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0131 - mae: 0.0906
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0127 - mae: 0.1029
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0110 - mae: 0.0886
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0105 - mae: 0.0923
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0103 - mae: 0.0916
# Epoch 9/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0111 - mae: 0.0930
# Epoch 10/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0105 - mae: 0.0908
# Epoch 00010: early stopping
# 2017NC =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 1s 56ms/sample - loss: 1.9637 - mae: 0.9166
# Epoch 2/100
# 25/25 [==============================] - 0s 4ms/sample - loss: 0.0117 - mae: 0.0944
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0083 - mae: 0.0779
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0040 - mae: 0.0550
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0029 - mae: 0.0433
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0024 - mae: 0.0396
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0024 - mae: 0.0432
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0025 - mae: 0.0421
# Epoch 00008: early stopping
# 2017HT =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 2s 62ms/sample - loss: 1.4551 - mae: 0.9458
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0373 - mae: 0.1678
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0149 - mae: 0.1001
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0135 - mae: 0.0888
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0101 - mae: 0.0871
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0108 - mae: 0.0862
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0102 - mae: 0.0844
# Epoch 00007: early stopping
# 2017SK =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 1s 60ms/sample - loss: 1.8775 - mae: 0.9052
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0125 - mae: 0.0980
# Epoch 3/100
# 25/25 [==============================] - 0s 4ms/sample - loss: 0.0094 - mae: 0.0787
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0034 - mae: 0.0483
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0029 - mae: 0.0449
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0030 - mae: 0.0455
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0030 - mae: 0.0480
# Epoch 00007: early stopping
# 2017KT =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 2s 60ms/sample - loss: 1.8309 - mae: 0.9138
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0187 - mae: 0.1222
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0102 - mae: 0.0841
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0043 - mae: 0.0470
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0028 - mae: 0.0422
# Epoch 6/100
# 25/25 [==============================] - 0s 4ms/sample - loss: 0.0026 - mae: 0.0445
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0024 - mae: 0.0377
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0024 - mae: 0.0372
# Epoch 9/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0024 - mae: 0.0417
# Epoch 10/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0025 - mae: 0.0399
# Epoch 11/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0024 - mae: 0.0376 0s - loss: 0.0026 - mae: 0.038
# Epoch 12/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0024 - mae: 0.0423
# Epoch 13/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0024 - mae: 0.0369
# Epoch 00013: early stopping
# 2017WO =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 1s 55ms/sample - loss: 1.3673 - mae: 0.8949
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0234 - mae: 0.1296
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0127 - mae: 0.1006
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0029 - mae: 0.0370
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0032 - mae: 0.0388
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0026 - mae: 0.0413
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0027 - mae: 0.0436
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0027 - mae: 0.0416
# Epoch 00008: early stopping
# 2017LT =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 1s 56ms/sample - loss: 1.0012 - mae: 0.7809
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0322 - mae: 0.1626
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0084 - mae: 0.0758
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0057 - mae: 0.0626
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0050 - mae: 0.0586
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0049 - mae: 0.0542
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0041 - mae: 0.0497
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0040 - mae: 0.0484
# Epoch 9/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0041 - mae: 0.0498
# Epoch 10/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0041 - mae: 0.0499
# Epoch 00010: early stopping
# 2017SS =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 1s 54ms/sample - loss: 1.3879 - mae: 0.8504
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0235 - mae: 0.1232
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0104 - mae: 0.0827
# Epoch 4/100
# 25/25 [==============================] - 0s 2ms/sample - loss: 0.0031 - mae: 0.0459
# Epoch 5/100
# 25/25 [==============================] - 0s 2ms/sample - loss: 0.0026 - mae: 0.0422
# Epoch 6/100
# 25/25 [==============================] - 0s 2ms/sample - loss: 0.0023 - mae: 0.0375
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0023 - mae: 0.0383
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0025 - mae: 0.0409
# Epoch 9/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0023 - mae: 0.0370
# Epoch 10/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0022 - mae: 0.0367
# Epoch 11/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0023 - mae: 0.0403
# Epoch 12/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0023 - mae: 0.0363
# Epoch 00012: early stopping
# 2017OB =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 3s 108ms/sample - loss: 2.0266 - mae: 1.0090
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0090 - mae: 0.0780
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0047 - mae: 0.0571
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0011 - mae: 0.0285
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0014 - mae: 0.0314
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0013 - mae: 0.0298
# Epoch 00006: early stopping
# 2018LG =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 2s 60ms/sample - loss: 0.5893 - mae: 0.5293
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0120 - mae: 0.0943
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0054 - mae: 0.0642
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0046 - mae: 0.0562
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0039 - mae: 0.0527
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0036 - mae: 0.0504
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0034 - mae: 0.0489
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0031 - mae: 0.0460
# Epoch 9/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0033 - mae: 0.0459
# Epoch 10/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0036 - mae: 0.0482
# Epoch 00010: early stopping
# 2018HH =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 1s 58ms/sample - loss: 1.4394 - mae: 0.7555
# Epoch 2/100
# 25/25 [==============================] - 0s 4ms/sample - loss: 0.0245 - mae: 0.1338
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0074 - mae: 0.0684
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0038 - mae: 0.0514
# Epoch 5/100
# 25/25 [==============================] - 0s 2ms/sample - loss: 0.0034 - mae: 0.0463
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0025 - mae: 0.0371
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0025 - mae: 0.0356
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0023 - mae: 0.0383
# Epoch 9/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0025 - mae: 0.0359
# Epoch 10/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0022 - mae: 0.0379
# Epoch 11/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0021 - mae: 0.0340
# Epoch 12/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0021 - mae: 0.0334
# Epoch 13/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0021 - mae: 0.0335
# Epoch 14/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0021 - mae: 0.0376
# Epoch 15/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0018 - mae: 0.0312
# Epoch 16/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0017 - mae: 0.0301
# Epoch 17/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0017 - mae: 0.0311
# Epoch 18/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0017 - mae: 0.0337
# Epoch 19/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0018 - mae: 0.0348
# Epoch 20/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0015 - mae: 0.0288
# Epoch 21/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0019 - mae: 0.0350
# Epoch 22/100
# 25/25 [==============================] - 0s 4ms/sample - loss: 0.0015 - mae: 0.0297
# Epoch 23/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0013 - mae: 0.0278
# Epoch 24/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0013 - mae: 0.0286
# Epoch 25/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0013 - mae: 0.0276
# Epoch 26/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0012 - mae: 0.0275
# Epoch 27/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0012 - mae: 0.0287
# Epoch 28/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0013 - mae: 0.0302
# Epoch 00028: early stopping
# 2018NC =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 1s 56ms/sample - loss: 1.3057 - mae: 0.8277
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0201 - mae: 0.1228
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0047 - mae: 0.0536
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0062 - mae: 0.0654
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0044 - mae: 0.0555
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0043 - mae: 0.0542
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0043 - mae: 0.0554
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0039 - mae: 0.0520
# Epoch 9/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0046 - mae: 0.0565
# Epoch 10/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0040 - mae: 0.0536
# Epoch 00010: early stopping
# 2018HT =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 1s 57ms/sample - loss: 1.3578 - mae: 0.8783
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0349 - mae: 0.1701
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0048 - mae: 0.0581
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0059 - mae: 0.0600
# Epoch 5/100
# 25/25 [==============================] - 0s 2ms/sample - loss: 0.0047 - mae: 0.0546
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0048 - mae: 0.0603
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0033 - mae: 0.0508
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0035 - mae: 0.0524
# Epoch 9/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0034 - mae: 0.0517
# Epoch 00009: early stopping
# 2018SK =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 1s 55ms/sample - loss: 1.3543 - mae: 0.8749
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0215 - mae: 0.1244
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0113 - mae: 0.0846
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0061 - mae: 0.0684
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0050 - mae: 0.0606
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0046 - mae: 0.0582
# Epoch 7/100
# 25/25 [==============================] - 0s 2ms/sample - loss: 0.0047 - mae: 0.0602
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0050 - mae: 0.0618
# Epoch 00008: early stopping
# 2018KT =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 1s 58ms/sample - loss: 1.0918 - mae: 0.8099
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0313 - mae: 0.1534
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0072 - mae: 0.0680
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0047 - mae: 0.0525
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0037 - mae: 0.0550
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0045 - mae: 0.0532
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0039 - mae: 0.0554
# Epoch 00007: early stopping
# 2018WO =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 1s 56ms/sample - loss: 1.2431 - mae: 0.8269
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0373 - mae: 0.1747
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0163 - mae: 0.1053
# Epoch 4/100
# 25/25 [==============================] - 0s 2ms/sample - loss: 0.0083 - mae: 0.0659
# Epoch 5/100
# 25/25 [==============================] - 0s 2ms/sample - loss: 0.0064 - mae: 0.0717
# Epoch 6/100
# 25/25 [==============================] - 0s 2ms/sample - loss: 0.0064 - mae: 0.0609
# Epoch 7/100
# 25/25 [==============================] - 0s 2ms/sample - loss: 0.0061 - mae: 0.0596
# Epoch 8/100
# 25/25 [==============================] - 0s 2ms/sample - loss: 0.0072 - mae: 0.0770
# Epoch 9/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0058 - mae: 0.0599
# Epoch 10/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0058 - mae: 0.0597
# Epoch 11/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0067 - mae: 0.0711
# Epoch 12/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0073 - mae: 0.0558
# Epoch 00012: early stopping
# 2018LT =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 1s 58ms/sample - loss: 2.3354 - mae: 1.0201
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0316 - mae: 0.1582
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0061 - mae: 0.0652
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0082 - mae: 0.0787
# Epoch 5/100
# 25/25 [==============================] - 0s 2ms/sample - loss: 0.0061 - mae: 0.0681
# Epoch 6/100
# 25/25 [==============================] - 0s 2ms/sample - loss: 0.0059 - mae: 0.0665
# Epoch 7/100
# 25/25 [==============================] - 0s 2ms/sample - loss: 0.0060 - mae: 0.0660
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0053 - mae: 0.0630
# Epoch 9/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0056 - mae: 0.0658
# Epoch 10/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0055 - mae: 0.0651
# Epoch 00010: early stopping
# 2018SS =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 1s 59ms/sample - loss: 1.5999 - mae: 0.8913
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0145 - mae: 0.1007
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0094 - mae: 0.0795
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0044 - mae: 0.0543
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0059 - mae: 0.0634
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0050 - mae: 0.0561
# Epoch 00006: early stopping
# 2018OB =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# ...
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 2s 69ms/sample - loss: 1.6433 - mae: 0.9430
# Epoch 2/100
# 25/25 [==============================] - 0s 5ms/sample - loss: 0.0103 - mae: 0.0905
# Epoch 3/100
# 25/25 [==============================] - 0s 4ms/sample - loss: 0.0057 - mae: 0.0595
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0021 - mae: 0.0386
# Epoch 5/100
# 25/25 [==============================] - 0s 4ms/sample - loss: 0.0013 - mae: 0.0299
# Epoch 6/100
# 25/25 [==============================] - 0s 5ms/sample - loss: 0.0013 - mae: 0.0300
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0012 - mae: 0.0278
# Epoch 8/100
# 25/25 [==============================] - 0s 2ms/sample - loss: 0.0011 - mae: 0.0265
# Epoch 9/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0012 - mae: 0.0281
# Epoch 10/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0011 - mae: 0.0270
# Epoch 00010: early stopping
# 2019HH =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 2s 60ms/sample - loss: 1.8585 - mae: 0.8788
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0517 - mae: 0.2011
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0163 - mae: 0.1133
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0067 - mae: 0.0677
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0045 - mae: 0.0584
# Epoch 6/100
# 25/25 [==============================] - 0s 2ms/sample - loss: 0.0044 - mae: 0.0566
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0046 - mae: 0.0594
# Epoch 8/100
# 25/25 [==============================] - 0s 2ms/sample - loss: 0.0045 - mae: 0.0573
# Epoch 00008: early stopping
# 2019NC =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 2s 64ms/sample - loss: 1.0892 - mae: 0.8536
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0280 - mae: 0.1302
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0118 - mae: 0.1035
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0022 - mae: 0.0388
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0011 - mae: 0.0257
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 7.3081e-04 - mae: 0.0222
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 6.2740e-04 - mae: 0.0186
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 4.9879e-04 - mae: 0.0172
# Epoch 9/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 5.3816e-04 - mae: 0.0168
# Epoch 10/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 5.1435e-04 - mae: 0.0167
# Epoch 00010: early stopping
# 2019HT =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 2s 66ms/sample - loss: 1.6349 - mae: 0.8609
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0309 - mae: 0.1664
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0055 - mae: 0.0610
# Epoch 4/100
# 25/25 [==============================] - 0s 2ms/sample - loss: 0.0058 - mae: 0.0604
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0045 - mae: 0.0585
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0033 - mae: 0.0500
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0034 - mae: 0.0505
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0032 - mae: 0.0502
# Epoch 9/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0033 - mae: 0.0501
# Epoch 10/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0032 - mae: 0.0501
# Epoch 11/100
# 25/25 [==============================] - 0s 4ms/sample - loss: 0.0031 - mae: 0.0493
# Epoch 12/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0031 - mae: 0.0490
# Epoch 13/100
# 25/25 [==============================] - 0s 2ms/sample - loss: 0.0032 - mae: 0.0495
# Epoch 14/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0032 - mae: 0.0491
# Epoch 00014: early stopping
# 2019SK =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 1s 57ms/sample - loss: 1.7568 - mae: 1.0010
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0260 - mae: 0.1449
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0080 - mae: 0.0752
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0051 - mae: 0.0572
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0027 - mae: 0.0433
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0026 - mae: 0.0431
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0029 - mae: 0.0448
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0025 - mae: 0.0424
# Epoch 9/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0026 - mae: 0.0430
# Epoch 10/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0028 - mae: 0.0447
# Epoch 00010: early stopping
# 2019KT =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 2s 65ms/sample - loss: 1.2106 - mae: 0.8441
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0198 - mae: 0.1244
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0107 - mae: 0.0869
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0065 - mae: 0.0695
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0055 - mae: 0.0652
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0050 - mae: 0.0629 0s - loss: 0.0046 - mae: 0.060
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0056 - mae: 0.0655
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0054 - mae: 0.0629
# Epoch 00008: early stopping
# 2019WO =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 2s 76ms/sample - loss: 1.4958 - mae: 0.9075
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0466 - mae: 0.1983
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0096 - mae: 0.0817
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0044 - mae: 0.0545
# Epoch 5/100
# 25/25 [==============================] - 0s 2ms/sample - loss: 0.0035 - mae: 0.0462
# Epoch 6/100
# 25/25 [==============================] - 0s 2ms/sample - loss: 0.0033 - mae: 0.0495
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0035 - mae: 0.0494
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0034 - mae: 0.0504
# Epoch 00008: early stopping
# 2019LT =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 2s 78ms/sample - loss: 1.9099 - mae: 0.9172
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0428 - mae: 0.1923
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0093 - mae: 0.0778
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0039 - mae: 0.0528
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0021 - mae: 0.0390
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0026 - mae: 0.0386
# Epoch 7/100
# 25/25 [==============================] - 0s 2ms/sample - loss: 0.0024 - mae: 0.0408
# Epoch 00007: early stopping
# 2019SS =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 3s 133ms/sample - loss: 1.0236 - mae: 0.8010
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0289 - mae: 0.1610
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0060 - mae: 0.0654
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0036 - mae: 0.0467
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0023 - mae: 0.0397
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0015 - mae: 0.0311
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0015 - mae: 0.0322
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0017 - mae: 0.0325
# Epoch 9/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0017 - mae: 0.0352
# Epoch 00009: early stopping
# 2019OB =======================================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               63200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 63,301
# Trainable params: 63,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25 samples
# Epoch 1/100
# 25/25 [==============================] - 2s 84ms/sample - loss: 0.9178 - mae: 0.7328
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0128 - mae: 0.1010
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0061 - mae: 0.0671
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0050 - mae: 0.0572
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0037 - mae: 0.0514
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0030 - mae: 0.0456
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0035 - mae: 0.0501
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/sample - loss: 0.0032 - mae: 0.0465
# Epoch 00008: early stopping

# %%
# # 100, lr = 0.01, batch 2
# test_pred_df.sort_values(by=["YEAR","T_ID"]).to_csv("PCT_3.csv",index = False
#                                                 )

# %%
test_pred_df.groupby(["YEAR"]).mean()
# Out:
#              y    y_pred  shift_PCT_1  shift_PCT_2       rms    rms0.5
# YEAR
# 2016  0.492391  0.495652     0.504167     0.508514  0.070957  0.075725
# 2017  0.498370  0.489564     0.491848     0.521937  0.122198  0.076630
# 2018  0.507971  0.496652     0.500362     0.497480  0.095594  0.071377
# 2019  0.505072  0.498990     0.508152     0.495290  0.096964  0.105072

# %%
mean_squared_error(test_pred_df['y'],test_pred_df['y_pred'])
# Out:
# 0.015411139084997588

# %%
test_pred_df
# Out:
#     YEAR T_ID         y    y_pred  shift_PCT_1  shift_PCT_2  shift_PCT_3  \
# 0   2016   LG  0.608696  0.629710     0.583333     0.458333     0.375000
# 1   2016   HH  0.500000  0.522560     0.500000     0.608696     0.521739
# 2   2016   NC  0.565217  0.519151     0.500000     0.541667     0.739130
# 3   2016   HT  0.458333  0.572146     0.500000     0.583333     0.458333
# 4   2016   SK  0.458333  0.432622     0.458333     0.458333     0.458333
# 5   2016   KT  0.291667  0.306353     0.333333     0.375000     0.416667
# 6   2016   WO  0.375000  0.563867     0.625000     0.666667     0.500000
# 7   2016   LT  0.500000  0.403313     0.375000     0.500000     0.458333
# 8   2016   SS  0.500000  0.499762     0.500000     0.434783     0.333333
# 9   2016   OB  0.666667  0.520579     0.666667     0.458333     0.666667
# 10  2017   LG  0.434783  0.541557     0.304348     0.652174     0.500000
# 11  2017   HH  0.434783  0.406909     0.541667     0.333333     0.478261
# 12  2017   NC  0.500000  0.506327     0.458333     0.541667     0.625000
# 13  2017   HT  0.500000  0.503643     0.500000     0.782609     0.583333
# 14  2017   SK  0.625000  0.342055     0.458333     0.416667     0.666667
# 15  2017   KT  0.500000  0.297826     0.333333     0.166667     0.166667
# 16  2017   WO  0.347826  0.521394     0.500000     0.541667     0.500000
# 17  2017   LT  0.666667  0.601711     0.750000     0.590909     0.375000
# 18  2017   SS  0.391304  0.432068     0.333333     0.454545     0.625000
# 19  2017   OB  0.583333  0.787650     0.739130     0.739130     0.416667
# 20  2018   LG  0.416667  0.335831     0.291667     0.478261     0.708333
# 21  2018   HH  0.500000  0.488470     0.416667     0.583333     0.541667
# 22  2018   NC  0.416667  0.523539     0.521739     0.416667     0.333333
# 23  2018   HT  0.541667  0.412760     0.541667     0.375000     0.458333
# 24  2018   SK  0.458333  0.565601     0.500000     0.666667     0.478261
# 25  2018   KT  0.391304  0.450082     0.416667     0.545455     0.291667
# 26  2018   WO  0.541667  0.493151     0.666667     0.458333     0.500000
# 27  2018   LT  0.666667  0.462636     0.458333     0.347826     0.478261
# 28  2018   SS  0.521739  0.616615     0.565217     0.478261     0.521739
# 29  2018   OB  0.625000  0.576834     0.625000     0.625000     0.708333
# 30  2019   LG  0.541667  0.501315     0.541667     0.500000     0.695652
# 31  2019   HH  0.583333  0.276836     0.375000     0.250000     0.291667
# 32  2019   NC  0.565217  0.520843     0.541667     0.478261     0.333333
# 33  2019   HT  0.500000  0.498890     0.478261     0.416667     0.541667
# 34  2019   SK  0.375000  0.642783     0.625000     0.708333     0.666667
# 35  2019   KT  0.541667  0.581655     0.521739     0.652174     0.500000
# 36  2019   WO  0.666667  0.657315     0.565217     0.708333     0.541667
# 37  2019   LT  0.208333  0.383863     0.391304     0.304348     0.434783
# 38  2019   SS  0.416667  0.415163     0.375000     0.434783     0.458333
# 39  2019   OB  0.652174  0.527475     0.666667     0.500000     0.500000
#
#          rms    rms0.5
# 0   0.021015  0.108696
# 1   0.022560  0.000000
# 2   0.046066  0.065217
# 3   0.113812  0.041667
# 4   0.025711  0.041667
# 5   0.014687  0.208333
# 6   0.188867  0.125000
# 7   0.096687  0.000000
# 8   0.000238  0.000000
# 9   0.146087  0.166667
# 10  0.106775  0.065217
# 11  0.027873  0.065217
# 12  0.006327  0.000000
# 13  0.003643  0.000000
# 14  0.282945  0.125000
# 15  0.202174  0.000000
# 16  0.173568  0.152174
# 17  0.064956  0.166667
# 18  0.040764  0.108696
# 19  0.204317  0.083333
# 20  0.080836  0.083333
# 21  0.011530  0.000000
# 22  0.106872  0.083333
# 23  0.128907  0.041667
# 24  0.107267  0.041667
# 25  0.058778  0.108696
# 26  0.048516  0.041667
# 27  0.204031  0.166667
# 28  0.094875  0.021739
# 29  0.048166  0.125000
# 30  0.040352  0.041667
# 31  0.306497  0.083333
# 32  0.044375  0.065217
# 33  0.001110  0.000000
# 34  0.267783  0.125000
# 35  0.039988  0.041667
# 36  0.009352  0.166667
# 37  0.175530  0.291667
# 38  0.001503  0.083333
# 39  0.124699  0.152174

# %% [markdown]
# ## +)

# %%
# 100, lr = 0.01, batch 10
test_pred_df
# Out:
#     YEAR T_ID         y    y_pred  shift_PCT_1  shift_PCT_2       rms  \
# 0   2016   LG  0.608696  0.324510     0.583333     0.458333  0.284185
# 1   2016   HH  0.500000  0.620822     0.500000     0.608696  0.120822
# 2   2016   NC  0.565217  0.315737     0.500000     0.541667  0.249481
# 3   2016   HT  0.458333  0.732308     0.500000     0.583333  0.273975
# 4   2016   SK  0.458333  0.608401     0.458333     0.458333  0.150068
# 5   2016   KT  0.291667  0.362899     0.333333     0.375000  0.071232
# 6   2016   WO  0.375000  0.764267     0.625000     0.666667  0.389267
# 7   2016   LT  0.500000  0.532504     0.375000     0.500000  0.032504
# 8   2016   SS  0.500000  0.655361     0.500000     0.434783  0.155361
# 9   2016   OB  0.666667  0.320553     0.666667     0.458333  0.346113
# 10  2017   LG  0.434783 -0.054497     0.304348     0.652174  0.489280
# 11  2017   HH  0.434783  0.296570     0.541667     0.333333  0.138213
# 12  2017   NC  0.500000  0.653593     0.458333     0.541667  0.153593
# 13  2017   HT  0.500000  0.364929     0.500000     0.782609  0.135071
# 14  2017   SK  0.625000 -0.038210     0.458333     0.416667  0.663210
# 15  2017   KT  0.500000  0.477115     0.333333     0.166667  0.022885
# 16  2017   WO  0.347826  0.627553     0.500000     0.541667  0.279727
# 17  2017   LT  0.666667  0.701589     0.750000     0.590909  0.034923
# 18  2017   SS  0.391304  0.053972     0.333333     0.454545  0.337332
# 19  2017   OB  0.583333  0.385147     0.739130     0.739130  0.198186
# 20  2018   LG  0.416667  0.579832     0.291667     0.478261  0.163165
# 21  2018   HH  0.500000  0.629360     0.416667     0.583333  0.129360
# 22  2018   NC  0.416667  0.673886     0.521739     0.416667  0.257219
# 23  2018   HT  0.541667  0.167681     0.541667     0.375000  0.373986
# 24  2018   SK  0.458333  0.784004     0.500000     0.666667  0.325671
# 25  2018   KT  0.391304  0.613142     0.416667     0.545455  0.221838
# 26  2018   WO  0.541667  0.613035     0.666667     0.458333  0.071368
# 27  2018   LT  0.666667  0.313228     0.458333     0.347826  0.353439
# 28  2018   SS  0.521739  0.705813     0.565217     0.478261  0.184074
# 29  2018   OB  0.625000  0.666161     0.625000     0.625000  0.041161
# 30  2019   LG  0.541667  0.730977     0.541667     0.500000  0.189310
# 31  2019   HH  0.583333  0.452957     0.375000     0.250000  0.130376
# 32  2019   NC  0.565217  0.671601     0.541667     0.478261  0.106384
# 33  2019   HT  0.500000  0.319585     0.478261     0.416667  0.180415
# 34  2019   SK  0.375000  0.865226     0.625000     0.708333  0.490226
# 35  2019   KT  0.541667  0.309915     0.521739     0.652174  0.231751
# 36  2019   WO  0.666667  0.330414     0.565217     0.708333  0.336253
# 37  2019   LT  0.208333  0.589169     0.391304     0.304348  0.380836
# 38  2019   SS  0.416667  0.635856     0.375000     0.434783  0.219189
# 39  2019   OB  0.652174  0.163353     0.666667     0.500000  0.488820
#
#       rms0.5
# 0   0.108696
# 1   0.000000
# 2   0.065217
# 3   0.041667
# 4   0.041667
# 5   0.208333
# 6   0.125000
# 7   0.000000
# 8   0.000000
# 9   0.166667
# 10  0.065217
# 11  0.065217
# 12  0.000000
# 13  0.000000
# 14  0.125000
# 15  0.000000
# 16  0.152174
# 17  0.166667
# 18  0.108696
# 19  0.083333
# 20  0.083333
# 21  0.000000
# 22  0.083333
# 23  0.041667
# 24  0.041667
# 25  0.108696
# 26  0.041667
# 27  0.166667
# 28  0.021739
# 29  0.125000
# 30  0.041667
# 31  0.083333
# 32  0.065217
# 33  0.000000
# 34  0.125000
# 35  0.041667
# 36  0.166667
# 37  0.291667
# 38  0.083333
# 39  0.152174

# %%
test_pred_df.groupby(["YEAR"]).mean()
# Out:
#              y    y_pred  shift_PCT_1  shift_PCT_2       rms    rms0.5
# YEAR
# 2016  0.492391  0.523736     0.504167     0.508514  0.207301  0.075725
# 2017  0.498370  0.346776     0.491848     0.521937  0.245242  0.076630
# 2018  0.507971  0.574614     0.500362     0.497480  0.212128  0.071377
# 2019  0.505072  0.506905     0.508152     0.495290  0.275356  0.105072

# %%
# 100, lr = 0.01, batch 5
test_pred_df
# Out:
#     YEAR T_ID         y    y_pred  shift_PCT_1  shift_PCT_2       rms  \
# 0   2016   LG  0.608696  0.703705     0.583333     0.458333  0.095009
# 1   2016   HH  0.500000  0.505495     0.500000     0.608696  0.005495
# 2   2016   NC  0.565217  0.590402     0.500000     0.541667  0.025184
# 3   2016   HT  0.458333  0.552457     0.500000     0.583333  0.094123
# 4   2016   SK  0.458333  0.508638     0.458333     0.458333  0.050305
# 5   2016   KT  0.291667  0.410087     0.333333     0.375000  0.118421
# 6   2016   WO  0.375000  0.706302     0.625000     0.666667  0.331302
# 7   2016   LT  0.500000  0.345885     0.375000     0.500000  0.154115
# 8   2016   SS  0.500000  0.630994     0.500000     0.434783  0.130994
# 9   2016   OB  0.666667  0.577408     0.666667     0.458333  0.089259
# 10  2017   LG  0.434783  0.532804     0.304348     0.652174  0.098022
# 11  2017   HH  0.434783  0.450112     0.541667     0.333333  0.015330
# 12  2017   NC  0.500000  0.570386     0.458333     0.541667  0.070386
# 13  2017   HT  0.500000  0.493522     0.500000     0.782609  0.006478
# 14  2017   SK  0.625000  0.399854     0.458333     0.416667  0.225146
# 15  2017   KT  0.500000  0.218301     0.333333     0.166667  0.281699
# 16  2017   WO  0.347826  0.589394     0.500000     0.541667  0.241568
# 17  2017   LT  0.666667  0.659785     0.750000     0.590909  0.006881
# 18  2017   SS  0.391304  0.416450     0.333333     0.454545  0.025146
# 19  2017   OB  0.583333  0.864256     0.739130     0.739130  0.280922
# 20  2018   LG  0.416667  0.429864     0.291667     0.478261  0.013197
# 21  2018   HH  0.500000  0.407442     0.416667     0.583333  0.092558
# 22  2018   NC  0.416667  0.494825     0.521739     0.416667  0.078158
# 23  2018   HT  0.541667  0.552897     0.541667     0.375000  0.011230
# 24  2018   SK  0.458333  0.609713     0.500000     0.666667  0.151380
# 25  2018   KT  0.391304  0.559332     0.416667     0.545455  0.168028
# 26  2018   WO  0.541667  0.430332     0.666667     0.458333  0.111335
# 27  2018   LT  0.666667  0.524269     0.458333     0.347826  0.142398
# 28  2018   SS  0.521739  0.605838     0.565217     0.478261  0.084099
# 29  2018   OB  0.625000  0.630527     0.625000     0.625000  0.005527
# 30  2019   LG  0.541667  0.483113     0.541667     0.500000  0.058554
# 31  2019   HH  0.583333  0.324708     0.375000     0.250000  0.258626
# 32  2019   NC  0.565217  0.590590     0.541667     0.478261  0.025372
# 33  2019   HT  0.500000  0.579354     0.478261     0.416667  0.079354
# 34  2019   SK  0.375000  0.671998     0.625000     0.708333  0.296998
# 35  2019   KT  0.541667  0.535633     0.521739     0.652174  0.006034
# 36  2019   WO  0.666667  0.723131     0.565217     0.708333  0.056464
# 37  2019   LT  0.208333  0.278328     0.391304     0.304348  0.069995
# 38  2019   SS  0.416667  0.505280     0.375000     0.434783  0.088613
# 39  2019   OB  0.652174  0.495743     0.666667     0.500000  0.156431
#
#       rms0.5
# 0   0.108696
# 1   0.000000
# 2   0.065217
# 3   0.041667
# 4   0.041667
# 5   0.208333
# 6   0.125000
# 7   0.000000
# 8   0.000000
# 9   0.166667
# 10  0.065217
# 11  0.065217
# 12  0.000000
# 13  0.000000
# 14  0.125000
# 15  0.000000
# 16  0.152174
# 17  0.166667
# 18  0.108696
# 19  0.083333
# 20  0.083333
# 21  0.000000
# 22  0.083333
# 23  0.041667
# 24  0.041667
# 25  0.108696
# 26  0.041667
# 27  0.166667
# 28  0.021739
# 29  0.125000
# 30  0.041667
# 31  0.083333
# 32  0.065217
# 33  0.000000
# 34  0.125000
# 35  0.041667
# 36  0.166667
# 37  0.291667
# 38  0.083333
# 39  0.152174

# %%
test_pred_df.groupby(["YEAR"]).mean()
# Out:
#              y    y_pred  shift_PCT_1  shift_PCT_2       rms    rms0.5
# YEAR
# 2016  0.492391  0.553137     0.504167     0.508514  0.109421  0.075725
# 2017  0.498370  0.519487     0.491848     0.521937  0.125158  0.076630
# 2018  0.507971  0.524504     0.500362     0.497480  0.085791  0.071377
# 2019  0.505072  0.518788     0.508152     0.495290  0.109644  0.105072

# %%
# 100, lr = 0.01, batch 2
test_pred_df
# Out:
#     YEAR T_ID         y    y_pred  shift_PCT_1  shift_PCT_2       rms  \
# 0   2016   LG  0.608696  0.639421     0.583333     0.458333  0.030725
# 1   2016   HH  0.500000  0.519752     0.500000     0.608696  0.019752
# 2   2016   NC  0.565217  0.521629     0.500000     0.541667  0.043589
# 3   2016   HT  0.458333  0.557003     0.500000     0.583333  0.098669
# 4   2016   SK  0.458333  0.434201     0.458333     0.458333  0.024132
# 5   2016   KT  0.291667  0.321546     0.333333     0.375000  0.029879
# 6   2016   WO  0.375000  0.588199     0.625000     0.666667  0.213199
# 7   2016   LT  0.500000  0.385834     0.375000     0.500000  0.114166
# 8   2016   SS  0.500000  0.500726     0.500000     0.434783  0.000726
# 9   2016   OB  0.666667  0.495426     0.666667     0.458333  0.171241
# 10  2017   LG  0.434783  0.529796     0.304348     0.652174  0.095014
# 11  2017   HH  0.434783  0.397498     0.541667     0.333333  0.037284
# 12  2017   NC  0.500000  0.506624     0.458333     0.541667  0.006624
# 13  2017   HT  0.500000  0.535533     0.500000     0.782609  0.035533
# 14  2017   SK  0.625000  0.337753     0.458333     0.416667  0.287247
# 15  2017   KT  0.500000  0.278858     0.333333     0.166667  0.221142
# 16  2017   WO  0.347826  0.527530     0.500000     0.541667  0.179704
# 17  2017   LT  0.666667  0.602771     0.750000     0.590909  0.063895
# 18  2017   SS  0.391304  0.389925     0.333333     0.454545  0.001379
# 19  2017   OB  0.583333  0.777300     0.739130     0.739130  0.193967
# 20  2018   LG  0.416667  0.355157     0.291667     0.478261  0.061510
# 21  2018   HH  0.500000  0.459926     0.416667     0.583333  0.040074
# 22  2018   NC  0.416667  0.528158     0.521739     0.416667  0.111492
# 23  2018   HT  0.541667  0.404830     0.541667     0.375000  0.136837
# 24  2018   SK  0.458333  0.533757     0.500000     0.666667  0.075423
# 25  2018   KT  0.391304  0.492720     0.416667     0.545455  0.101415
# 26  2018   WO  0.541667  0.505432     0.666667     0.458333  0.036235
# 27  2018   LT  0.666667  0.422535     0.458333     0.347826  0.244132
# 28  2018   SS  0.521739  0.591848     0.565217     0.478261  0.070109
# 29  2018   OB  0.625000  0.576918     0.625000     0.625000  0.048082
# 30  2019   LG  0.541667  0.510082     0.541667     0.500000  0.031585
# 31  2019   HH  0.583333  0.310466     0.375000     0.250000  0.272867
# 32  2019   NC  0.565217  0.539832     0.541667     0.478261  0.025385
# 33  2019   HT  0.500000  0.511437     0.478261     0.416667  0.011437
# 34  2019   SK  0.375000  0.655191     0.625000     0.708333  0.280191
# 35  2019   KT  0.541667  0.604527     0.521739     0.652174  0.062861
# 36  2019   WO  0.666667  0.656901     0.565217     0.708333  0.009766
# 37  2019   LT  0.208333  0.356834     0.391304     0.304348  0.148500
# 38  2019   SS  0.416667  0.407614     0.375000     0.434783  0.009052
# 39  2019   OB  0.652174  0.516372     0.666667     0.500000  0.135802
#
#       rms0.5
# 0   0.108696
# 1   0.000000
# 2   0.065217
# 3   0.041667
# 4   0.041667
# 5   0.208333
# 6   0.125000
# 7   0.000000
# 8   0.000000
# 9   0.166667
# 10  0.065217
# 11  0.065217
# 12  0.000000
# 13  0.000000
# 14  0.125000
# 15  0.000000
# 16  0.152174
# 17  0.166667
# 18  0.108696
# 19  0.083333
# 20  0.083333
# 21  0.000000
# 22  0.083333
# 23  0.041667
# 24  0.041667
# 25  0.108696
# 26  0.041667
# 27  0.166667
# 28  0.021739
# 29  0.125000
# 30  0.041667
# 31  0.083333
# 32  0.065217
# 33  0.000000
# 34  0.125000
# 35  0.041667
# 36  0.166667
# 37  0.291667
# 38  0.083333
# 39  0.152174

# %%
test_pred_df.groupby(["YEAR"]).mean()
# Out:
#              y    y_pred  shift_PCT_1  shift_PCT_2       rms    rms0.5
# YEAR
# 2016  0.492391  0.496374     0.504167     0.508514  0.074608  0.075725
# 2017  0.498370  0.488359     0.491848     0.521937  0.112179  0.076630
# 2018  0.507971  0.487128     0.500362     0.497480  0.092531  0.071377
# 2019  0.505072  0.506926     0.508152     0.495290  0.098745  0.105072

# %%
# 100, lr = 0.01, batch 1
test_pred_df
# Out:
#     YEAR T_ID         y    y_pred  shift_PCT_1  shift_PCT_2       rms  \
# 0   2016   LG  0.608696  0.640221     0.583333     0.458333  0.031525
# 1   2016   HH  0.500000  0.551892     0.500000     0.608696  0.051892
# 2   2016   NC  0.565217  0.487683     0.500000     0.541667  0.077534
# 3   2016   HT  0.458333  0.545832     0.500000     0.583333  0.087499
# 4   2016   SK  0.458333  0.436860     0.458333     0.458333  0.021474
# 5   2016   KT  0.291667  0.348948     0.333333     0.375000  0.057281
# 6   2016   WO  0.375000  0.560369     0.625000     0.666667  0.185369
# 7   2016   LT  0.500000  0.352799     0.375000     0.500000  0.147201
# 8   2016   SS  0.500000  0.483279     0.500000     0.434783  0.016721
# 9   2016   OB  0.666667  0.516517     0.666667     0.458333  0.150149
# 10  2017   LG  0.434783  0.420091     0.304348     0.652174  0.014691
# 11  2017   HH  0.434783  0.372181     0.541667     0.333333  0.062602
# 12  2017   NC  0.500000  0.529463     0.458333     0.541667  0.029463
# 13  2017   HT  0.500000  0.511981     0.500000     0.782609  0.011981
# 14  2017   SK  0.625000  0.313708     0.458333     0.416667  0.311292
# 15  2017   KT  0.500000  0.305908     0.333333     0.166667  0.194092
# 16  2017   WO  0.347826  0.536220     0.500000     0.541667  0.188394
# 17  2017   LT  0.666667  0.576042     0.750000     0.590909  0.090624
# 18  2017   SS  0.391304  0.481664     0.333333     0.454545  0.090360
# 19  2017   OB  0.583333  0.784367     0.739130     0.739130  0.201034
# 20  2018   LG  0.416667  0.376348     0.291667     0.478261  0.040319
# 21  2018   HH  0.500000  0.499471     0.416667     0.583333  0.000529
# 22  2018   NC  0.416667  0.552205     0.521739     0.416667  0.135538
# 23  2018   HT  0.541667  0.411315     0.541667     0.375000  0.130352
# 24  2018   SK  0.458333  0.551030     0.500000     0.666667  0.092697
# 25  2018   KT  0.391304  0.485648     0.416667     0.545455  0.094344
# 26  2018   WO  0.541667  0.536453     0.666667     0.458333  0.005214
# 27  2018   LT  0.666667  0.428293     0.458333     0.347826  0.238374
# 28  2018   SS  0.521739  0.626056     0.565217     0.478261  0.104317
# 29  2018   OB  0.625000  0.580130     0.625000     0.625000  0.044870
# 30  2019   LG  0.541667  0.482156     0.541667     0.500000  0.059511
# 31  2019   HH  0.583333  0.266631     0.375000     0.250000  0.316702
# 32  2019   NC  0.565217  0.531603     0.541667     0.478261  0.033614
# 33  2019   HT  0.500000  0.479168     0.478261     0.416667  0.020832
# 34  2019   SK  0.375000  0.723102     0.625000     0.708333  0.348102
# 35  2019   KT  0.541667  0.579141     0.521739     0.652174  0.037474
# 36  2019   WO  0.666667  0.653043     0.565217     0.708333  0.013623
# 37  2019   LT  0.208333  0.371402     0.391304     0.304348  0.163069
# 38  2019   SS  0.416667  0.397205     0.375000     0.434783  0.019462
# 39  2019   OB  0.652174  0.493740     0.666667     0.500000  0.158434
#
#       rms0.5
# 0   0.108696
# 1   0.000000
# 2   0.065217
# 3   0.041667
# 4   0.041667
# 5   0.208333
# 6   0.125000
# 7   0.000000
# 8   0.000000
# 9   0.166667
# 10  0.065217
# 11  0.065217
# 12  0.000000
# 13  0.000000
# 14  0.125000
# 15  0.000000
# 16  0.152174
# 17  0.166667
# 18  0.108696
# 19  0.083333
# 20  0.083333
# 21  0.000000
# 22  0.083333
# 23  0.041667
# 24  0.041667
# 25  0.108696
# 26  0.041667
# 27  0.166667
# 28  0.021739
# 29  0.125000
# 30  0.041667
# 31  0.083333
# 32  0.065217
# 33  0.000000
# 34  0.125000
# 35  0.041667
# 36  0.166667
# 37  0.291667
# 38  0.083333
# 39  0.152174

# %%
test_pred_df.groupby(["YEAR"]).mean()
# Out:
#              y    y_pred  shift_PCT_1  shift_PCT_2       rms    rms0.5
# YEAR
# 2016  0.492391  0.492440     0.504167     0.508514  0.082665  0.075725
# 2017  0.498370  0.483163     0.491848     0.521937  0.119453  0.076630
# 2018  0.507971  0.504695     0.500362     0.497480  0.088655  0.071377
# 2019  0.505072  0.497719     0.508152     0.495290  0.117082  0.105072

# %% [markdown]
# #### +======================================+

# %%
test_pred_df #300, lr = 0.01

# %%
test_pred_df #300, lr = 0.001

# %%
test_pred_df #300, lr = 0.0005

# %%
test_pred_df #100, lr = 0.1

# %%
test_pred_df #100, lr = 0.01, patience 3

# %%
test_pred_df #100, lr = 0.01, patience 1

# %%
 #100, lr = 0.01, patience 2 +++, rms ver, rms05 ver, Adam

test_pred_df

# %%
 #100, lr = 0.01, patience 2 +++, rms ver, rms05 ver
# model_copy = model_dict.copy()
# hist_copy = hist_dict.copy()
# tmp_df = test_pred_df.copy()
tmp_df

# %%
test_pred_df #100, lr = 0.01, patience 2 +++, rms ver

# %%
test_pred_df #100, lr = 0.01, patience 2 ++

# %%
test_pred_df #100, lr = 0.01, patience 2

# %%
test_pred_df #100, lr = 0.01

# %%
test_pred_df #100, lr = 0.001

# %%
test_pred_df #100, lr = 0.001

# %%
test_pred_df #100, lr=0.0005

# %%
test_pred_df #200, lr = 0.01

# %%
test_pred_df #200, lr = 0.001

# %%
test_pred_df #200, lr=0.0005

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist1.history['loss'], 'y', label='train loss')

acc_ax.plot(hist1.history['mae'], 'b', label='train mae')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('mae')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()
